# %% [markdown]
# #1.Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5
# T(n) = 3T(n-1) + 12n
#
# To find the value of T(1)
# T(1) = 3T(1-1) +12(1)
# T(1) = 3T(0) + 12(1) ------>(1)
# substute T(0) = 5 in equation(1)
# T(1) = 3*5 + 12
# T(1) =15+12 = 27
#
# now, again,
#
# T(2) = 3T(2-1) + 12(2)
# T(2) = 3T(1) + 12(2) ------>(2)
# After that T(1) value substitute in equation 2
#
# T(2) =3(27)+24
# T(2) =81+24
# T(2) = 105
#   Therefore T(2) = 105
#  :: The value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n is 105.

# %% [markdown]
# #2. Given a recurrence relation, solve it using the substitution method:
#
# a. T(n) = T(n-1) + c
#
# Lets expand T(n - 1)cc
# T(n)=T(n-1 -1) +c
# T(n)=(T(n-2)+c)+c
# T(n)=T(n-2)+2c
# T(n)=T(n-3)+3c
# |
# |
# T(n)=T(1)+(n-1)c
# so, the solution is T(n) = T(1) + (n-1)c
#
#
# b. T(n) = 2T(n/2) + n
#
# Assume that T(k) = ck-d for constants c and d
# Now,substitue this assumption into the recurrence releation
# T(k) = 2(c(n/2)-d)+n
# T(k) = 2cn/2-2d+n
# T(k) = cn-2d+n
# now, set the equation to the assumed form
# cn-2d+n = ck-d
# solve for c and d
# c = 2
# d = n
# so,the solution is T(n)=2n-n = n
#
# c.T(n) = 2T(n/2) + c
#
# Assume that T(k) = ck for constant c
# T(n) = 2T(n/2) + c
# T(n) = 2c(n/2) + c
# T(n) = 2cn/2 + c
# T(n) = cn + c
# so, the solution is T(n) = cn + c
#
# d.T(n)=T(n/2)+c
#
# Assume that T(k) =ck for some constant c
# T(n) = c(n/2) + c
# T(n) = cn/2 + c
# so, the solution is T(n) = cn/2 + csss

# %% [markdown]
# #3. Given a recurrence relation, solve it using the recursive tree approach:
#
# a. T(n) = 2T(n-1) +1
# first,Draw the recursive tree for the recurrence relation
#
#                       T(n)
#                      /   \
#                  T(n-1)   T(n-1)
#                    / \     / \
#                T(n-2) T(n-2) T(n-2) T(n-2)
#                 / \    / \    / \    / \
#            T(n-3) ... T(n-3) T(n-3) T(n-3)
# At each Level The Recurrence branches into two subproblems of  size n - 1,and the work done at each level is 1.
# The total number of levels in recursive tree is n. Lets count the work done at each level.
# Level 0 = 1 work
# Level 1 = 2 work
# Level 2 = 2^2 work
# Level 3 = 2^3 work
# .....
# Level k = 2^k work
# The total work done is the sum of these geometric series
# 1 + 2 + 2^2 + 2^3 +....+ 2^(n-1) = 2^n -1
# The solution is T(n) = 2^n - 1
#
#
# b. T(n) = 2T(n/2) + n
#
#                    T(n)
#                    / \
#              T(n/2) T(n/2)
#               / \      / \
#           T(n/4) ... T(n/4) T(n/4) ...
#
# At each level, the recurrence branches into two subproblems of size n/2 and the work done by each level is n.
# The total number of recursion tree level is log(n) base 2.now counts the work done at each level.
# Level 0 = n work
# Level 1 = 2.n/2 = n work
# Level 2 = 2^2.n/2^2 = n works
# Level 3 = 2^3.n/2^3 = n works
# ..............
# Level k = 2^k.n/2^k = n works
# The total work done is the product of the work at each level and the number of nodes at each level:
# n.log(n) Base 2
#
# Therefore , the solution is T(n) = n.log base2(n)
